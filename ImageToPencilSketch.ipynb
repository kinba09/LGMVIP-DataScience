# %% [markdown]
# <a href="https://colab.research.google.com/github/kinba09/LGMVIP-DataScience/blob/main/ImageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("download.png")
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=200x251>
# -1

# %%
gr_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gr_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=200x251>
# -1

# %%
invert = 255 - gr_image
cv2_imshow(invert)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=200x251>
# -1

# %%
blurr = cv2.GaussianBlur(invert, (21, 21), 0)

# %%
invert = 255 - blurr
pencil_sketch = cv2.divide(gr_image, invert, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=200x251>
# -1

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=200x251>
# <PIL.Image.Image image mode=L size=200x251>
